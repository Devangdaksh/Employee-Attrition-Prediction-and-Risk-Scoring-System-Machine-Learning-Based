# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 data_dir = Path("data")
#       5 data_path = data_dir / "Palo Alto Networks.csv"
#       6
#       7 if not data_path.exists():
# ----> 8     raise FileNotFoundError(
#       9         f"{data_path} not found. Available CSV files: {[p.name for p in data_dir.glob('*.csv')]}"
#      10     )
#      11
#
# FileNotFoundError: data/Palo Alto Networks.csv not found. Available CSV files: []
